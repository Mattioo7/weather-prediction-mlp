# %% [markdown]
# # Notebook do testowania klasy WeatherConfig

# %%
from weather.config import WeatherConfig
from weather.dataset import build_dataset
from weather.normalization import normalize_global

cfg = WeatherConfig(
    data_dir="../data",
    target="temperature",
)

cfg.aggregations = {
    "temperature": ["mean", "min", "max"],
    "humidity": ["mean", "min", "max"],
    "pressure": ["mean", "min", "max"],
    "wind_speed": ["mean", "max"],
    "wind_direction": ["mean"],
}

cfg.cities = ["Vancouver", "Portland"]

X, Y = build_dataset(cfg, verbose="debug")
# X, mu, sigma = normalize_global(X)
# Out:
# === BUILD DATASET START ===
# Data directory: /home/matti/1. Mati/MSI - semestr 2/Sieci neuronowe/Projekt 3 - Weather prediction/data
# Target variable: temperature
# Window size (I): 3, Skip day X: True
# Max missing ratio per day: 0.3
# Input variables: ('temperature', 'humidity', 'pressure', 'wind_speed', 'wind_direction')
# Loading temperature_train.csv
# temperature: shape=(36516, 36)
# Loading humidity_train.csv
# humidity: shape=(36516, 36)
# Loading pressure_train.csv
# pressure: shape=(36516, 36)
# Loading wind_speed_train.csv
# wind_speed: shape=(36516, 36)
# Loading wind_direction_train.csv
# wind_direction: shape=(36516, 36)
# Number of cities: 2
#
# --- City [1/2]: Vancouver ---
# Total days available: 1522
#   Processing day I: 2012-10-01
#     REJECT day 2012-10-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-02
#     REJECT day 2012-10-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-03
#     REJECT day 2012-10-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-04
#     REJECT day 2012-10-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-05
#     REJECT day 2012-10-05 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-06
#   Processing day I: 2012-10-07
#     REJECT day 2012-10-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-07
#     REJECT day 2012-10-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-08
#     REJECT day 2012-10-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-09
#     REJECT day 2012-10-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-10
#   Processing day I: 2012-10-11
#     REJECT day 2012-10-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-11
#     REJECT day 2012-10-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-12
#     REJECT day 2012-10-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-13
#     REJECT day 2012-10-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-14
#     REJECT day 2012-10-14 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-15
#     REJECT day 2012-10-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-16
#     REJECT day 2012-10-16 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-10-17
#     REJECT day 2012-10-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-18
#   Processing day I: 2012-10-19
#   Processing day I: 2012-10-20
#     REJECT day 2012-10-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-19
#   Processing day I: 2012-10-20
#     REJECT day 2012-10-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-20
#     REJECT day 2012-10-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-21
#     REJECT day 2012-10-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-22
#     REJECT day 2012-10-22 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-23
#   Processing day I: 2012-10-24
#     REJECT day 2012-10-24 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-24
#     REJECT day 2012-10-24 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-25
#   Processing day I: 2012-10-26
#   Processing day I: 2012-10-27
#   Processing day I: 2012-10-26
#   Processing day I: 2012-10-27
#   Processing day I: 2012-10-28
#     REJECT day 2012-10-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-27
#   Processing day I: 2012-10-28
#     REJECT day 2012-10-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-28
#     REJECT day 2012-10-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-29
#     REJECT day 2012-10-29 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-10-30
#   Processing day I: 2012-10-31
#   Processing day I: 2012-11-01
#   Processing day I: 2012-10-31
#   Processing day I: 2012-11-01
#   Processing day I: 2012-11-02
#     REJECT day 2012-11-02 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-11-01
#   Processing day I: 2012-11-02
#     REJECT day 2012-11-02 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-11-02
#     REJECT day 2012-11-02 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-11-03
#   Processing day I: 2012-11-04
#     REJECT day 2012-11-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-04
#     REJECT day 2012-11-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-05
#     REJECT day 2012-11-05 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-11-06
#   Processing day I: 2012-11-07
#   Processing day I: 2012-11-08
#   Processing day I: 2012-11-07
#   Processing day I: 2012-11-08
#   Processing day I: 2012-11-09
#   Processing day I: 2012-11-08
#   Processing day I: 2012-11-09
#   Processing day I: 2012-11-10
#   Processing day I: 2012-11-09
#   Processing day I: 2012-11-10
#   Processing day I: 2012-11-11
#   Processing day I: 2012-11-10
#   Processing day I: 2012-11-11
#   Processing day I: 2012-11-12
#   Processing day I: 2012-11-11
#   Processing day I: 2012-11-12
#   Processing day I: 2012-11-13
#   Processing day I: 2012-11-12
#   Processing day I: 2012-11-13
#   Processing day I: 2012-11-14
#   Processing day I: 2012-11-13
#   Processing day I: 2012-11-14
#   Processing day I: 2012-11-15
#     REJECT day 2012-11-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-14
#   Processing day I: 2012-11-15
#     REJECT day 2012-11-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-15
#     REJECT day 2012-11-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-16
#   Processing day I: 2012-11-17
#     REJECT day 2012-11-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-17
#     REJECT day 2012-11-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-18
#     REJECT day 2012-11-18 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-19
#     REJECT day 2012-11-19 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-20
#     REJECT day 2012-11-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-21
#     REJECT day 2012-11-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-22
#     REJECT day 2012-11-22 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-23
#     REJECT day 2012-11-23 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-24
#     REJECT day 2012-11-24 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-25
#     REJECT day 2012-11-25 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-26
#     REJECT day 2012-11-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-27
#     REJECT day 2012-11-27 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-11-28
#     REJECT day 2012-11-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-29
#     REJECT day 2012-11-29 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-11-30
#     REJECT day 2012-11-30 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-01
#     REJECT day 2012-12-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-02
#     REJECT day 2012-12-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-03
#     REJECT day 2012-12-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-04
#     REJECT day 2012-12-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-05
#     REJECT day 2012-12-05 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-06
#     REJECT day 2012-12-06 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-07
#     REJECT day 2012-12-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-08
#     REJECT day 2012-12-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-09
#   Processing day I: 2012-12-10
#     REJECT day 2012-12-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-10
#     REJECT day 2012-12-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-11
#     REJECT day 2012-12-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-12
#     REJECT day 2012-12-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-13
#     REJECT day 2012-12-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-14
#     REJECT day 2012-12-14 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-15
#     REJECT day 2012-12-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-16
#     REJECT day 2012-12-16 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-17
#     REJECT day 2012-12-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-18
#     REJECT day 2012-12-18 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-19
#     REJECT day 2012-12-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-20
#     REJECT day 2012-12-20 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-21
#     REJECT day 2012-12-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2012-12-22
#     REJECT day 2012-12-22 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-23
#   Processing day I: 2012-12-24
#   Processing day I: 2012-12-25
#   Processing day I: 2012-12-24
#   Processing day I: 2012-12-25
#   Processing day I: 2012-12-26
#   Processing day I: 2012-12-25
#   Processing day I: 2012-12-26
#   Processing day I: 2012-12-27
#     REJECT day 2012-12-27 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-26
#   Processing day I: 2012-12-27
#     REJECT day 2012-12-27 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-27
#     REJECT day 2012-12-27 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-28
#   Processing day I: 2012-12-29
#   Processing day I: 2012-12-30
#   Processing day I: 2012-12-29
#   Processing day I: 2012-12-30
#   Processing day I: 2012-12-31
#     REJECT day 2012-12-31 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-30
#   Processing day I: 2012-12-31
#     REJECT day 2012-12-31 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2012-12-31
#     REJECT day 2012-12-31 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-01
#     REJECT day 2013-01-01 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-02
#     REJECT day 2013-01-02 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-03
#   Processing day I: 2013-01-04
#     REJECT day 2013-01-04 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-04
#     REJECT day 2013-01-04 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-05
#     REJECT day 2013-01-05 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-06
#     REJECT day 2013-01-06 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-07
#     REJECT day 2013-01-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-08
#     REJECT day 2013-01-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-09
#     REJECT day 2013-01-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-10
#     REJECT day 2013-01-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-11
#     REJECT day 2013-01-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-12
#     REJECT day 2013-01-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-13
#     REJECT day 2013-01-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-14
#     REJECT day 2013-01-14 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-15
#     REJECT day 2013-01-15 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-16
#     REJECT day 2013-01-16 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-17
#     REJECT day 2013-01-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-18
#     REJECT day 2013-01-18 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-19
#     REJECT day 2013-01-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-20
#     REJECT day 2013-01-20 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-01-21
#     REJECT day 2013-01-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-22
#     REJECT day 2013-01-22 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-23
#     REJECT day 2013-01-23 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-24
#     REJECT day 2013-01-24 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-25
#     REJECT day 2013-01-25 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-26
#     REJECT day 2013-01-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-27
#     REJECT day 2013-01-27 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-28
#     REJECT day 2013-01-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-29
#   Processing day I: 2013-01-30
#     REJECT day 2013-01-30 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-30
#     REJECT day 2013-01-30 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-01-31
#     REJECT day 2013-01-31 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-01
#     REJECT day 2013-02-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-02
#     REJECT day 2013-02-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-03
#     REJECT day 2013-02-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-04
#     REJECT day 2013-02-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-05
#     REJECT day 2013-02-05 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-06
#     REJECT day 2013-02-06 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-07
#     REJECT day 2013-02-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-08
#     REJECT day 2013-02-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-09
#     REJECT day 2013-02-09 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-02-10
#     REJECT day 2013-02-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-11
#     REJECT day 2013-02-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-12
#     REJECT day 2013-02-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-13
#     REJECT day 2013-02-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-14
#     REJECT day 2013-02-14 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-15
#     REJECT day 2013-02-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-16
#     REJECT day 2013-02-16 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-17
#     REJECT day 2013-02-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-18
#     REJECT day 2013-02-18 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-19
#     REJECT day 2013-02-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-02-20
#     REJECT day 2013-02-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-21
#     REJECT day 2013-02-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-22
#     REJECT day 2013-02-22 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-23
#     REJECT day 2013-02-23 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-24
#     REJECT day 2013-02-24 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-02-25
#     REJECT day 2013-02-25 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-26
#     REJECT day 2013-02-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-27
#     REJECT day 2013-02-27 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-02-28
#     REJECT day 2013-02-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-01
#     REJECT day 2013-03-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-02
#     REJECT day 2013-03-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-03
#     REJECT day 2013-03-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-04
#     REJECT day 2013-03-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-05
#     REJECT day 2013-03-05 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-06
#     REJECT day 2013-03-06 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-07
#     REJECT day 2013-03-07 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-08
#     REJECT day 2013-03-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-09
#     REJECT day 2013-03-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-10
#     REJECT day 2013-03-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-11
#     REJECT day 2013-03-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-12
#     REJECT day 2013-03-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-13
#     REJECT day 2013-03-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-14
#     REJECT day 2013-03-14 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-15
#     REJECT day 2013-03-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-16
#     REJECT day 2013-03-16 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-03-17
#     REJECT day 2013-03-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-18
#     REJECT day 2013-03-18 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-19
#   Processing day I: 2013-03-20
#   Processing day I: 2013-03-21
#   Processing day I: 2013-03-20
#   Processing day I: 2013-03-21
#   Processing day I: 2013-03-22
#   Processing day I: 2013-03-21
#   Processing day I: 2013-03-22
#   Processing day I: 2013-03-23
#   Processing day I: 2013-03-22
#   Processing day I: 2013-03-23
#   Processing day I: 2013-03-24
#   Processing day I: 2013-03-23
#   Processing day I: 2013-03-24
#   Processing day I: 2013-03-25
#   Processing day I: 2013-03-24
#   Processing day I: 2013-03-25
#   Processing day I: 2013-03-26
#   Processing day I: 2013-03-25
#   Processing day I: 2013-03-26
#   Processing day I: 2013-03-27
#   Processing day I: 2013-03-26
#   Processing day I: 2013-03-27
#   Processing day I: 2013-03-28
#     REJECT day 2013-03-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-27
#   Processing day I: 2013-03-28
#     REJECT day 2013-03-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-28
#     REJECT day 2013-03-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-29
#     REJECT day 2013-03-29 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-30
#   Processing day I: 2013-03-31
#     REJECT day 2013-03-31 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-03-31
#     REJECT day 2013-03-31 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-01
#     REJECT day 2013-04-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-02
#     REJECT day 2013-04-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-03
#     REJECT day 2013-04-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-04
#     REJECT day 2013-04-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-05
#     REJECT day 2013-04-05 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-06
#     REJECT day 2013-04-06 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-07
#   Processing day I: 2013-04-08
#     REJECT day 2013-04-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-08
#     REJECT day 2013-04-08 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-09
#   Processing day I: 2013-04-10
#     REJECT day 2013-04-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-10
#     REJECT day 2013-04-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-11
#     REJECT day 2013-04-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-12
#   Processing day I: 2013-04-13
#   Processing day I: 2013-04-14
#     REJECT day 2013-04-14 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-13
#   Processing day I: 2013-04-14
#     REJECT day 2013-04-14 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-14
#     REJECT day 2013-04-14 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-15
#     REJECT day 2013-04-15 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-16
#     REJECT day 2013-04-16 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-17
#     REJECT day 2013-04-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-18
#   Processing day I: 2013-04-19
#     REJECT day 2013-04-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-19
#     REJECT day 2013-04-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-20
#     REJECT day 2013-04-20 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-04-21
#   Processing day I: 2013-04-22
#   Processing day I: 2013-04-23
#   Processing day I: 2013-04-22
#   Processing day I: 2013-04-23
#   Processing day I: 2013-04-24
#   Processing day I: 2013-04-23
#   Processing day I: 2013-04-24
#   Processing day I: 2013-04-25
#   Processing day I: 2013-04-24
#   Processing day I: 2013-04-25
#   Processing day I: 2013-04-26
#     REJECT day 2013-04-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-25
#   Processing day I: 2013-04-26
#     REJECT day 2013-04-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-26
#     REJECT day 2013-04-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-27
#     REJECT day 2013-04-27 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-28
#     REJECT day 2013-04-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-29
#     REJECT day 2013-04-29 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-04-30
#     REJECT day 2013-04-30 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-01
#     REJECT day 2013-05-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-02
#     REJECT day 2013-05-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-03
#     REJECT day 2013-05-03 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-04
#     REJECT day 2013-05-04 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-05
#     REJECT day 2013-05-05 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-06
#   Processing day I: 2013-05-07
#   Processing day I: 2013-05-08
#   Processing day I: 2013-05-07
#   Processing day I: 2013-05-08
#   Processing day I: 2013-05-09
#     REJECT day 2013-05-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-08
#   Processing day I: 2013-05-09
#     REJECT day 2013-05-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-09
#     REJECT day 2013-05-09 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-10
#     REJECT day 2013-05-10 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-11
#     REJECT day 2013-05-11 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-12
#     REJECT day 2013-05-12 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-13
#     REJECT day 2013-05-13 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-14
#     REJECT day 2013-05-14 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-15
#     REJECT day 2013-05-15 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-16
#     REJECT day 2013-05-16 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-17
#     REJECT day 2013-05-17 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-18
#     REJECT day 2013-05-18 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-19
#     REJECT day 2013-05-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-05-20
#     REJECT day 2013-05-20 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-21
#     REJECT day 2013-05-21 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-22
#     REJECT day 2013-05-22 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-23
#   Processing day I: 2013-05-24
#   Processing day I: 2013-05-25
#   Processing day I: 2013-05-24
#   Processing day I: 2013-05-25
#   Processing day I: 2013-05-26
#     REJECT day 2013-05-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-25
#   Processing day I: 2013-05-26
#     REJECT day 2013-05-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-26
#     REJECT day 2013-05-26 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-27
#     REJECT day 2013-05-27 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-28
#     REJECT day 2013-05-28 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-29
#     REJECT day 2013-05-29 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-30
#     REJECT day 2013-05-30 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-05-31
#     REJECT day 2013-05-31 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-06-01
#     REJECT day 2013-06-01 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-06-02
#     REJECT day 2013-06-02 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-06-03
#     REJECT day 2013-06-03 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-06-04
#     REJECT day 2013-06-04 | var=pressure | missing ratio too high or NaN
#   Processing day I: 2013-06-05
#   Processing day I: 2013-06-06
#   Processing day I: 2013-06-07
#   Processing day I: 2013-06-06
#   Processing day I: 2013-06-07
#   Processing day I: 2013-06-08
#   Processing day I: 2013-06-07
#   Processing day I: 2013-06-08
#   Processing day I: 2013-06-09
#   Processing day I: 2013-06-08
#   Processing day I: 2013-06-09
#   Processing day I: 2013-06-10
#   Processing day I: 2013-06-09
#   Processing day I: 2013-06-10
#   Processing day I: 2013-06-11
#   Processing day I: 2013-06-10
#   Processing day I: 2013-06-11
#   Processing day I: 2013-06-12
#   Processing day I: 2013-06-11
#   Processing day I: 2013-06-12
#   Processing day I: 2013-06-13
#   Processing day I: 2013-06-12
#   Processing day I: 2013-06-13
#   Processing day I: 2013-06-14
#   Processing day I: 2013-06-13
#   Processing day I: 2013-06-14
#   Processing day I: 2013-06-15
#   Processing day I: 2013-06-14
#   Processing day I: 2013-06-15
#   Processing day I: 2013-06-16
#   Processing day I: 2013-06-15
#   Processing day I: 2013-06-16
#   Processing day I: 2013-06-17
#   Processing day I: 2013-06-16
#   Processing day I: 2013-06-17
#   Processing day I: 2013-06-18
#   Processing day I: 2013-06-17
#   Processing day I: 2013-06-18
#   Processing day I: 2013-06-19
#   Processing day I: 2013-06-18
#   Processing day I: 2013-06-19
#   Processing day I: 2013-06-20
#   Processing day I: 2013-06-19
#   Processing day I: 2013-06-20
#   Processing day I: 2013-06-21
#   Processing day I: 2013-06-20
#   Processing day I: 2013-06-21
#   Processing day I: 2013-06-22
#   Processing day I: 2013-06-21
#   Processing day I: 2013-06-22
#   Processing day I: 2013-06-23
#   Processing day I: 2013-06-22
#   Processing day I: 2013-06-23
#   Processing day I: 2013-06-24
#   Processing day I: 2013-06-23
#   Processing day I: 2013-06-24
#   Processing day I: 2013-06-25
#   Processing day I: 2013-06-24
#   Processing day I: 2013-06-25
#   Processing day I: 2013-06-26
#   Processing day I: 2013-06-25
#   Processing day I: 2013-06-26
#   Processing day I: 2013-06-27
#   Processing day I: 2013-06-26
#   Processing day I: 2013-06-27
#   Processing day I: 2013-06-28
#   Processing day I: 2013-06-27
#   Processing day I: 2013-06-28
#   Processing day I: 2013-06-29
#   Processing day I: 2013-06-28
#   Processing day I: 2013-06-29
#   Processing day I: 2013-06-30
#   Processing day I: 2013-06-29
#   Processing day I: 2013-06-30
#   Processing day I: 2013-07-01
#   Processing day I: 2013-06-30
#   Processing day I: 2013-07-01
#   Processing day I: 2013-07-02
#   Processing day I: 2013-07-01
#   Processing day I: 2013-07-02
#   Processing day I: 2013-07-03
#   Processing day I: 2013-07-02
#   Processing day I: 2013-07-03
#   Processing day I: 2013-07-04
#   Processing day I: 2013-07-03
#   Processing day I: 2013-07-04
#   Processing day I: 2013-07-05
#   Processing day I: 2013-07-04
#   Processing day I: 2013-07-05
#   Processing day I: 2013-07-06
#   Processing day I: 2013-07-05
#   Processing day I: 2013-07-06
#   Processing day I: 2013-07-07
#   Processing day I: 2013-07-06
#   Processing day I: 2013-07-07
#   Processing day I: 2013-07-08
#   Processing day I: 2013-07-07
#   Processing day I: 2013-07-08
#   Processing day I: 2013-07-09
#   Processing day I: 2013-07-08
#   Processing day I: 2013-07-09
#   Processing day I: 2013-07-10
#   Processing day I: 2013-07-09
#   Processing day I: 2013-07-10
#   Processing day I: 2013-07-11
#   Processing day I: 2013-07-10
#   Processing day I: 2013-07-11
#   Processing day I: 2013-07-12
#   Processing day I: 2013-07-11
#   Processing day I: 2013-07-12
#   Processing day I: 2013-07-13
#   Processing day I: 2013-07-12
#   Processing day I: 2013-07-13
#   Processing day I: 2013-07-14
#   Processing day I: 2013-07-13
#   Processing day I: 2013-07-14
#   Processing day I: 2013-07-15
#   Processing day I: 2013-07-14
#   Processing day I: 2013-07-15
#   Processing day I: 2013-07-16
#   Processing day I: 2013-07-15
#   Processing day I: 2013-07-16
#   Processing day I: 2013-07-17
#   Processing day I: 2013-07-16
#   Processing day I: 2013-07-17
#   Processing day I: 2013-07-18
#   Processing day I: 2013-07-17
#   Processing day I: 2013-07-18
#   Processing day I: 2013-07-19
#   Processing day I: 2013-07-18
#   Processing day I: 2013-07-19
#   Processing day I: 2013-07-20
#   Processing day I: 2013-07-19
#   Processing day I: 2013-07-20
#   Processing day I: 2013-07-21
#   Processing day I: 2013-07-20
#   Processing day I: 2013-07-21
#   Processing day I: 2013-07-22
#   Processing day I: 2013-07-21
#   Processing day I: 2013-07-22
#   Processing day I: 2013-07-23
#   Processing day I: 2013-07-22
#   Processing day I: 2013-07-23
#   Processing day I: 2013-07-24
#   Processing day I: 2013-07-23
#   Processing day I: 2013-07-24
#   Processing day I: 2013-07-25
#   Processing day I: 2013-07-24
#   Processing day I: 2013-07-25
#   Processing day I: 2013-07-26
#   Processing day I: 2013-07-25
#   Processing day I: 2013-07-26
#   Processing day I: 2013-07-27
#   Processing day I: 2013-07-26
#   Processing day I: 2013-07-27
#   Processing day I: 2013-07-28
#   Processing day I: 2013-07-27
#   Processing day I: 2013-07-28
#   Processing day I: 2013-07-29
#   Processing day I: 2013-07-28
#   Processing day I: 2013-07-29
#   Processing day I: 2013-07-30
#   Processing day I: 2013-07-29
#   Processing day I: 2013-07-30
#   Processing day I: 2013-07-31
#   Processing day I: 2013-07-30
#   Processing day I: 2013-07-31
#   Processing day I: 2013-08-01
#   Processing day I: 2013-07-31
#   Processing day I: 2013-08-01
#   Processing day I: 2013-08-02
#   Processing day I: 2013-08-01
#   Processing day I: 2013-08-02
#   Processing day I: 2013-08-03
#   Processing day I: 2013-08-02
#   Processing day I: 2013-08-03
#   Processing day I: 2013-08-04
#   Processing day I: 2013-08-03
#   Processing day I: 2013-08-04
#   Processing day I: 2013-08-05
#   Processing day I: 2013-08-04
#   Processing day I: 2013-08-05
#   Processing day I: 2013-08-06
#   Processing day I: 2013-08-05
#   Processing day I: 2013-08-06
#   Processing day I: 2013-08-07
#   Processing day I: 2013-08-06
#   Processing day I: 2013-08-07
#   Processing day I: 2013-08-08
#   Processing day I: 2013-08-07
#   Processing day I: 2013-08-08
#   Processing day I: 2013-08-09
#   Processing day I: 2013-08-08
#   Processing day I: 2013-08-09
#   Processing day I: 2013-08-10
#   Processing day I: 2013-08-09
#   Processing day I: 2013-08-10
#   Processing day I: 2013-08-11
#   Processing day I: 2013-08-10
#   Processing day I: 2013-08-11
#   Processing day I: 2013-08-12
#   Processing day I: 2013-08-11
#   Processing day I: 2013-08-12
#   Processing day I: 2013-08-13
#   Processing day I: 2013-08-12
#   Processing day I: 2013-08-13
#   Processing day I: 2013-08-14
#   Processing day I: 2013-08-13
#   Processing day I: 2013-08-14
#   Processing day I: 2013-08-15
#   Processing day I: 2013-08-14
#   Processing day I: 2013-08-15
#   Processing day I: 2013-08-16
#   Processing day I: 2013-08-15
#   Processing day I: 2013-08-16
#   Processing day I: 2013-08-17
#   Processing day I: 2013-08-16
#   Processing day I: 2013-08-17
#   Processing day I: 2013-08-18
#   Processing day I: 2013-08-17
#   Processing day I: 2013-08-18
#   Processing day I: 2013-08-19
#   Processing day I: 2013-08-18
#   Processing day I: 2013-08-19
#   Processing day I: 2013-08-20
#   Processing day I: 2013-08-19
#   Processing day I: 2013-08-20
#   Processing day I: 2013-08-21
#   Processing day I: 2013-08-20
#   Processing day I: 2013-08-21
#   Processing day I: 2013-08-22
#   Processing day I: 2013-08-21
#   Processing day I: 2013-08-22
#   Processing day I: 2013-08-23
#   Processing day I: 2013-08-22
#   Processing day I: 2013-08-23
#   Processing day I: 2013-08-24
#   Processing day I: 2013-08-23
#   Processing day I: 2013-08-24
#   Processing day I: 2013-08-25
#   Processing day I: 2013-08-24
#   Processing day I: 2013-08-25
#   Processing day I: 2013-08-26
#   Processing day I: 2013-08-25
#   Processing day I: 2013-08-26
#   Processing day I: 2013-08-27
#   Processing day I: 2013-08-26
#   Processing day I: 2013-08-27
#   Processing day I: 2013-08-28
#   Processing day I: 2013-08-27
#   Processing day I: 2013-08-28
#   Processing day I: 2013-08-29
#   Processing day I: 2013-08-28
#   Processing day I: 2013-08-29
#   Processing day I: 2013-08-30
#   Processing day I: 2013-08-29
#   Processing day I: 2013-08-30
#   Processing day I: 2013-08-31
#   Processing day I: 2013-08-30
#   Processing day I: 2013-08-31
#   Processing day I: 2013-09-01
#   Processing day I: 2013-08-31
#   Processing day I: 2013-09-01
#   Processing day I: 2013-09-02
#   Processing day I: 2013-09-01
#   Processing day I: 2013-09-02
#   Processing day I: 2013-09-03
#   Processing day I: 2013-09-02
#   Processing day I: 2013-09-03
#   Processing day I: 2013-09-04
#   Processing day I: 2013-09-03
#   Processing day I: 2013-09-04
#   Processing day I: 2013-09-05
#   Processing day I: 2013-09-04
#   Processing day I: 2013-09-05
#   Processing day I: 2013-09-06
#   Processing day I: 2013-09-05
#   Processing day I: 2013-09-06
#   Processing day I: 2013-09-07
#   Processing day I: 2013-09-06
#   Processing day I: 2013-09-07
#   Processing day I: 2013-09-08
#   Processing day I: 2013-09-07
#   Processing day I: 2013-09-08
#   Processing day I: 2013-09-09
#   Processing day I: 2013-09-08
#   Processing day I: 2013-09-09
#   Processing day I: 2013-09-10
#   Processing day I: 2013-09-09
#   Processing day I: 2013-09-10
#   Processing day I: 2013-09-11
#   Processing day I: 2013-09-10
#   Processing day I: 2013-09-11
#   Processing day I: 2013-09-12
#   Processing day I: 2013-09-11
#   Processing day I: 2013-09-12
#   Processing day I: 2013-09-13
#   Processing day I: 2013-09-12
#   Processing day I: 2013-09-13
#   Processing day I: 2013-09-14
#   Processing day I: 2013-09-13
#   Processing day I: 2013-09-14
#   Processing day I: 2013-09-15
#   Processing day I: 2013-09-14
#   Processing day I: 2013-09-15
#   Processing day I: 2013-09-16
#   Processing day I: 2013-09-15
#   Processing day I: 2013-09-16
#   Processing day I: 2013-09-17
#   Processing day I: 2013-09-16
#   Processing day I: 2013-09-17
#   Processing day I: 2013-09-18
#   Processing day I: 2013-09-17
#   Processing day I: 2013-09-18
#   Processing day I: 2013-09-19
#   Processing day I: 2013-09-18
#   Processing day I: 2013-09-19
#   Processing day I: 2013-09-20
#   Processing day I: 2013-09-19
#   Processing day I: 2013-09-20
#   Processing day I: 2013-09-21
#   Processing day I: 2013-09-20
#   Processing day I: 2013-09-21
#   Processing day I: 2013-09-22
#   Processing day I: 2013-09-21
#   Processing day I: 2013-09-22
#   Processing day I: 2013-09-23
#   Processing day I: 2013-09-22
#   Processing day I: 2013-09-23
#   Processing day I: 2013-09-24
#   Processing day I: 2013-09-23
#   Processing day I: 2013-09-24
#   Processing day I: 2013-09-25
#   Processing day I: 2013-09-24
#   Processing day I: 2013-09-25
#   Processing day I: 2013-09-26
#   Processing day I: 2013-09-25
#   Processing day I: 2013-09-26
#   Processing day I: 2013-09-27
#   Processing day I: 2013-09-26
#   Processing day I: 2013-09-27
#   Processing day I: 2013-09-28
#   Processing day I: 2013-09-27
#   Processing day I: 2013-09-28
#   Processing day I: 2013-09-29
#   Processing day I: 2013-09-28
#   Processing day I: 2013-09-29
#   Processing day I: 2013-09-30
#   Processing day I: 2013-09-29
#   Processing day I: 2013-09-30
#   Processing day I: 2013-10-01
#   Processing day I: 2013-09-30
#   Processing day I: 2013-10-01
#   Processing day I: 2013-10-02
#   Processing day I: 2013-10-01
#   Processing day I: 2013-10-02
#   Processing day I: 2013-10-03
#   Processing day I: 2013-10-02
#   Processing day I: 2013-10-03
#   Processing day I: 2013-10-04
#   Processing day I: 2013-10-03
#   Processing day I: 2013-10-04
#   Processing day I: 2013-10-05
#   Processing day I: 2013-10-04
#   Processing day I: 2013-10-05
#   Processing day I: 2013-10-06
#   Processing day I: 2013-10-05
#   Processing day I: 2013-10-06
#   Processing day I: 2013-10-07
#   Processing day I: 2013-10-06
#   Processing day I: 2013-10-07
#   Processing day I: 2013-10-08
#   Processing day I: 2013-10-07
#   Processing day I: 2013-10-08
#   Processing day I: 2013-10-09
#   Processing day I: 2013-10-08
#   Processing day I: 2013-10-09
#   Processing day I: 2013-10-10
#   Processing day I: 2013-10-09
#   Processing day I: 2013-10-10
#   Processing day I: 2013-10-11
#   Processing day I: 2013-10-10
#   Processing day I: 2013-10-11
#   Processing day I: 2013-10-12
#   Processing day I: 2013-10-11
#   Processing day I: 2013-10-12
#   Processing day I: 2013-10-13
#   Processing day I: 2013-10-12
#   Processing day I: 2013-10-13
#   Processing day I: 2013-10-14
#   Processing day I: 2013-10-13
#   Processing day I: 2013-10-14
#   Processing day I: 2013-10-15
#   Processing day I: 2013-10-14
#   Processing day I: 2013-10-15
#   Processing day I: 2013-10-16
#   Processing day I: 2013-10-15
#   Processing day I: 2013-10-16
#   Processing day I: 2013-10-17
#   Processing day I: 2013-10-16
#   Processing day I: 2013-10-17
#   Processing day I: 2013-10-18
#   Processing day I: 2013-10-17
#   Processing day I: 2013-10-18
#   Processing day I: 2013-10-19
#     REJECT day 2013-10-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-10-18
#   Processing day I: 2013-10-19
#     REJECT day 2013-10-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-10-19
#     REJECT day 2013-10-19 | var=humidity | missing ratio too high or NaN
#   Processing day I: 2013-10-20
#   Processing day I: 2013-10-21
#   Processing day I: 2013-10-22
#   Processing day I: 2013-10-21
#   Processing day I: 2013-10-22
#   Processing day I: 2013-10-23
#   Processing day I: 2013-10-22
#   Processing day I: 2013-10-23
#   Processing day I: 2013-10-24
#   Processing day I: 2013-10-23
#   Processing day I: 2013-10-24
#   Processing day I: 2013-10-25
#   Processing day I: 2013-10-24
#   Processing day I: 2013-10-25
#   Processing day I: 2013-10-26
#   Processing day I: 2013-10-25
#   Processing day I: 2013-10-26
#   Processing day I: 2013-10-27
#   Processing day I: 2013-10-26
#   Processing day I: 2013-10-27
#   Processing day I: 2013-10-28
#   Processing day I: 2013-10-27
#   Processing day I: 2013-10-28
#   Processing day I: 2013-10-29
#   Processing day I: 2013-10-28
#   Processing day I: 2013-10-29
#   Processing day I: 2013-10-30
#   Processing day I: 2013-10-29
#   Processing day I: 2013-10-30
#   Processing day I: 2013-10-31
#   Processing day I: 2013-10-30
#   Processing day I: 2013-10-31
#   Processing day I: 2013-11-01
#   Processing day I: 2013-10-31
#   Processing day I: 2013-11-01
#   Processing day I: 2013-11-02
#   Processing day I: 2013-11-01
#   Processing day I: 2013-11-02
#   Processing day I: 2013-11-03
#   Processing day I: 2013-11-02
#   Processing day I: 2013-11-03
#   Processing day I: 2013-11-04
#   Processing day I: 2013-11-03
#   Processing day I: 2013-11-04
#   Processing day I: 2013-11-05
#   Processing day I: 2013-11-04
#   Processing day I: 2013-11-05
#   Processing day I: 2013-11-06
#   Processing day I: 2013-11-05
#   Processing day I: 2013-11-06
#   Processing day I: 2013-11-07
#   Processing day I: 2013-11-06
#   Processing day I: 2013-11-07
#   Processing day I: 2013-11-08
#   Processing day I: 2013-11-07
#   Processing day I: 2013-11-08
#   Processing day I: 2013-11-09
#   Processing day I: 2013-11-08
#   Processing day I: 2013-11-09
#   Processing day I: 2013-11-10
#   Processing day I: 2013-11-09
#   Processing day I: 2013-11-10
#   Processing day I: 2013-11-11
#   Processing day I: 2013-11-10
#   Processing day I: 2013-11-11
#   Processing day I: 2013-11-12
#   Processing day I: 2013-11-11
#   Processing day I: 2013-11-12
#   Processing day I: 2013-11-13
#   Processing day I: 2013-11-12
#   Processing day I: 2013-11-13
#   Processing day I: 2013-11-14
#   Processing day I: 2013-11-13
#   Processing day I: 2013-11-14
#   Processing day I: 2013-11-15
#   Processing day I: 2013-11-14
#   Processing day I: 2013-11-15
#   Processing day I: 2013-11-16
#   Processing day I: 2013-11-15
#   Processing day I: 2013-11-16
#   Processing day I: 2013-11-17
#   Processing day I: 2013-11-16
#   Processing day I: 2013-11-17
#   Processing day I: 2013-11-18
#   Processing day I: 2013-11-17
#   Processing day I: 2013-11-18
#   Processing day I: 2013-11-19
#   Processing day I: 2013-11-18
#   Processing day I: 2013-11-19
#   Processing day I: 2013-11-20
#   Processing day I: 2013-11-19
#   Processing day I: 2013-11-20
#   Processing day I: 2013-11-21
#   Processing day I: 2013-11-20
#   Processing day I: 2013-11-21
#   Processing day I: 2013-11-22
#   Processing day I: 2013-11-21
#   Processing day I: 2013-11-22
#   Processing day I: 2013-11-23
#   Processing day I: 2013-11-22
#   Processing day I: 2013-11-23
#   Processing day I: 2013-11-24
#   Processing day I: 2013-11-23
#   Processing day I: 2013-11-24
#   Processing day I: 2013-11-25
#   Processing day I: 2013-11-24
#   Processing day I: 2013-11-25
#   Processing day I: 2013-11-26
#   Processing day I: 2013-11-25
#   Processing day I: 2013-11-26
#   Processing day I: 2013-11-27
#   Processing day I: 2013-11-26
#   Processing day I: 2013-11-27
#   Processing day I: 2013-11-28
#   Processing day I: 2013-11-27
#   Processing day I: 2013-11-28
#   Processing day I: 2013-11-29
#   Processing day I: 2013-11-28
#   Processing day I: 2013-11-29
#   Processing day I: 2013-11-30
#   Processing day I: 2013-11-29
#   Processing day I: 2013-11-30
#   Processing day I: 2013-12-01
#   Processing day I: 2013-11-30
#   Processing day I: 2013-12-01
#   Processing day I: 2013-12-02
#   Processing day I: 2013-12-01
#   Processing day I: 2013-12-02
#   Processing day I: 2013-12-03
#   Processing day I: 2013-12-02
#   Processing day I: 2013-12-03
#   Processing day I: 2013-12-04
#   Processing day I: 2013-12-03
#   Processing day I: 2013-12-04
#   Processing day I: 2013-12-05
#   Processing day I: 2013-12-04
#   Processing day I: 2013-12-05
#   Processing day I: 2013-12-06
#   Processing day I: 2013-12-05
#   Processing day I: 2013-12-06
#   Processing day I: 2013-12-07
#   Processing day I: 2013-12-06
#   Processing day I: 2013-12-07
#   Processing day I: 2013-12-08
#   Processing day I: 2013-12-07
#   Processing day I: 2013-12-08
#   Processing day I: 2013-12-09
#   Processing day I: 2013-12-08
#   Processing day I: 2013-12-09
#   Processing day I: 2013-12-10
#   Processing day I: 2013-12-09
#   Processing day I: 2013-12-10
#   Processing day I: 2013-12-11
#   Processing day I: 2013-12-10
#   Processing day I: 2013-12-11
#   Processing day I: 2013-12-12
#   Processing day I: 2013-12-11
#   Processing day I: 2013-12-12
#   Processing day I: 2013-12-13
#   Processing day I: 2013-12-12
#   Processing day I: 2013-12-13
#   Processing day I: 2013-12-14
#   Processing day I: 2013-12-13
#   Processing day I: 2013-12-14
#   Processing day I: 2013-12-15
#   Processing day I: 2013-12-14
#   Processing day I: 2013-12-15
#   Processing day I: 2013-12-16
#   Processing day I: 2013-12-15
#   Processing day I: 2013-12-16
#   Processing day I: 2013-12-17
#   Processing day I: 2013-12-16
#   Processing day I: 2013-12-17
#   Processing day I: 2013-12-18
#   Processing day I: 2013-12-17
#   Processing day I: 2013-12-18
#   Processing day I: 2013-12-19
#   Processing day I: 2013-12-18
#   Processing day I: 2013-12-19
#   Processing day I: 2013-12-20
#   Processing day I: 2013-12-19
#   Processing day I: 2013-12-20
#   Processing day I: 2013-12-21
#   Processing day I: 2013-12-20
#   Processing day I: 2013-12-21
#   Processing day I: 2013-12-22
#   Processing day I: 2013-12-21
#   Processing day I: 2013-12-22
#   Processing day I: 2013-12-23
#   Processing day I: 2013-12-22
#   Processing day I: 2013-12-23
#   Processing day I: 2013-12-24
#   Processing day I: 2013-12-23
#   Processing day I: 2013-12-24
#   Processing day I: 2013-12-25
#   Processing day I: 2013-12-24
#   Processing day I: 2013-12-25
#   Processing day I: 2013-12-26
#   Processing day I: 2013-12-25
#   Processing day I: 2013-12-26
#   Processing day I: 2013-12-27
#   Processing day I: 2013-12-26
#   Processing day I: 2013-12-27
#   Processing day I: 2013-12-28
#   Processing day I: 2013-12-27
#   Processing day I: 2013-12-28
#   Processing day I: 2013-12-29
#   Processing day I: 2013-12-28
#   Processing day I: 2013-12-29
#   Processing day I: 2013-12-30
#   Processing day I: 2013-12-29
#   Processing day I: 2013-12-30
#   Processing day I: 2013-12-31
#   Processing day I: 2013-12-30
#   Processing day I: 2013-12-31
#   Processing day I: 2014-01-01
#   Processing day I: 2013-12-31
#   Processing day I: 2014-01-01
#   Processing day I: 2014-01-02
#   Processing day I: 2014-01-01
#   Processing day I: 2014-01-02
#   Processing day I: 2014-01-03
#   Processing day I: 2014-01-02
#   Processing day I: 2014-01-03
#   Processing day I: 2014-01-04
#   Processing day I: 2014-01-03
#   Processing day I: 2014-01-04
#   Processing day I: 2014-01-05
#   Processing day I: 2014-01-04
#   Processing day I: 2014-01-05
#   Processing day I: 2014-01-06
#   Processing day I: 2014-01-05
#   Processing day I: 2014-01-06
#   Processing day I: 2014-01-07
#   Processing day I: 2014-01-06
#   Processing day I: 2014-01-07
#   Processing day I: 2014-01-08
#   Processing day I: 2014-01-07
#   Processing day I: 2014-01-08
#   Processing day I: 2014-01-09
#   Processing day I: 2014-01-08
#   Processing day I: 2014-01-09
#   Processing day I: 2014-01-10
#   Processing day I: 2014-01-09
#   Processing day I: 2014-01-10
# ...
#   Processing day I: 2016-06-11
#   Processing day I: 2016-06-12
#   Processing day I: 2016-06-13
#   Processing day I: 2016-06-12
#   Processing day I: 2016-06-13
#   Processing day I: 2016-06-14
#   Processing day I: 2016-06-13
#   Processing day I: 2016-06-14
#   Processing day I: 2016-06-15
#   Processing day I: 2016-06-14
#   Processing day I: 2016-06-15
#   Processing day I: 2016-06-16
#   Processing day I: 2016-06-15
#   Processing day I: 2016-06-16
#   Processing day I: 2016-06-17
#   Processing day I: 2016-06-16
#   Processing day I: 2016-06-17
#   Processing day I: 2016-06-18
#   Processing day I: 2016-06-17
#   Processing day I: 2016-06-18
#   Processing day I: 2016-06-19
#   Processing day I: 2016-06-18
#   Processing day I: 2016-06-19
#   Processing day I: 2016-06-20
#   Processing day I: 2016-06-19
#   Processing day I: 2016-06-20
#   Processing day I: 2016-06-21
#   Processing day I: 2016-06-20
#   Processing day I: 2016-06-21
#   Processing day I: 2016-06-22
#   Processing day I: 2016-06-21
#   Processing day I: 2016-06-22
#   Processing day I: 2016-06-23
#   Processing day I: 2016-06-22
#   Processing day I: 2016-06-23
#   Processing day I: 2016-06-24
#   Processing day I: 2016-06-23
#   Processing day I: 2016-06-24
#   Processing day I: 2016-06-25
#   Processing day I: 2016-06-24
#   Processing day I: 2016-06-25
#   Processing day I: 2016-06-26
#   Processing day I: 2016-06-25
#   Processing day I: 2016-06-26
#   Processing day I: 2016-06-27
#   Processing day I: 2016-06-26
#   Processing day I: 2016-06-27
#   Processing day I: 2016-06-28
#   Processing day I: 2016-06-27
#   Processing day I: 2016-06-28
#   Processing day I: 2016-06-29
#   Processing day I: 2016-06-28
#   Processing day I: 2016-06-29
#   Processing day I: 2016-06-30
#   Processing day I: 2016-06-29
#   Processing day I: 2016-06-30
#   Processing day I: 2016-07-01
#   Processing day I: 2016-06-30
#   Processing day I: 2016-07-01
#   Processing day I: 2016-07-02
#   Processing day I: 2016-07-01
#   Processing day I: 2016-07-02
#   Processing day I: 2016-07-03
#   Processing day I: 2016-07-02
#   Processing day I: 2016-07-03
#   Processing day I: 2016-07-04
#   Processing day I: 2016-07-03
#   Processing day I: 2016-07-04
#   Processing day I: 2016-07-05
#   Processing day I: 2016-07-04
#   Processing day I: 2016-07-05
#   Processing day I: 2016-07-06
#   Processing day I: 2016-07-05
#   Processing day I: 2016-07-06
#   Processing day I: 2016-07-07
#   Processing day I: 2016-07-06
#   Processing day I: 2016-07-07
#   Processing day I: 2016-07-08
#   Processing day I: 2016-07-07
#   Processing day I: 2016-07-08
#   Processing day I: 2016-07-09
#   Processing day I: 2016-07-08
#   Processing day I: 2016-07-09
#   Processing day I: 2016-07-10
#   Processing day I: 2016-07-09
#   Processing day I: 2016-07-10
#   Processing day I: 2016-07-11
#   Processing day I: 2016-07-10
#   Processing day I: 2016-07-11
#   Processing day I: 2016-07-12
#   Processing day I: 2016-07-11
#   Processing day I: 2016-07-12
#   Processing day I: 2016-07-13
#   Processing day I: 2016-07-12
#   Processing day I: 2016-07-13
#   Processing day I: 2016-07-14
#   Processing day I: 2016-07-13
#   Processing day I: 2016-07-14
#   Processing day I: 2016-07-15
#   Processing day I: 2016-07-14
#   Processing day I: 2016-07-15
#   Processing day I: 2016-07-16
#   Processing day I: 2016-07-15
#   Processing day I: 2016-07-16
#   Processing day I: 2016-07-17
#   Processing day I: 2016-07-16
#   Processing day I: 2016-07-17
#   Processing day I: 2016-07-18
#   Processing day I: 2016-07-17
#   Processing day I: 2016-07-18
#   Processing day I: 2016-07-19
#   Processing day I: 2016-07-18
#   Processing day I: 2016-07-19
#   Processing day I: 2016-07-20
#   Processing day I: 2016-07-19
#   Processing day I: 2016-07-20
#   Processing day I: 2016-07-21
#   Processing day I: 2016-07-20
#   Processing day I: 2016-07-21
#   Processing day I: 2016-07-22
#   Processing day I: 2016-07-21
#   Processing day I: 2016-07-22
#   Processing day I: 2016-07-23
#   Processing day I: 2016-07-22
#   Processing day I: 2016-07-23
#   Processing day I: 2016-07-24
#   Processing day I: 2016-07-23
#   Processing day I: 2016-07-24
#   Processing day I: 2016-07-25
#   Processing day I: 2016-07-24
#   Processing day I: 2016-07-25
#   Processing day I: 2016-07-26
#   Processing day I: 2016-07-25
#   Processing day I: 2016-07-26
#   Processing day I: 2016-07-27
#   Processing day I: 2016-07-26
#   Processing day I: 2016-07-27
#   Processing day I: 2016-07-28
#   Processing day I: 2016-07-27
#   Processing day I: 2016-07-28
#   Processing day I: 2016-07-29
#   Processing day I: 2016-07-28
#   Processing day I: 2016-07-29
#   Processing day I: 2016-07-30
#   Processing day I: 2016-07-29
#   Processing day I: 2016-07-30
#   Processing day I: 2016-07-31
#   Processing day I: 2016-07-30
#   Processing day I: 2016-07-31
#   Processing day I: 2016-08-01
#   Processing day I: 2016-07-31
#   Processing day I: 2016-08-01
#   Processing day I: 2016-08-02
#   Processing day I: 2016-08-01
#   Processing day I: 2016-08-02
#   Processing day I: 2016-08-03
#   Processing day I: 2016-08-02
#   Processing day I: 2016-08-03
#   Processing day I: 2016-08-04
#   Processing day I: 2016-08-03
#   Processing day I: 2016-08-04
#   Processing day I: 2016-08-05
#   Processing day I: 2016-08-04
#   Processing day I: 2016-08-05
#   Processing day I: 2016-08-06
#   Processing day I: 2016-08-05
#   Processing day I: 2016-08-06
#   Processing day I: 2016-08-07
#   Processing day I: 2016-08-06
#   Processing day I: 2016-08-07
#   Processing day I: 2016-08-08
#   Processing day I: 2016-08-07
#   Processing day I: 2016-08-08
#   Processing day I: 2016-08-09
#   Processing day I: 2016-08-08
#   Processing day I: 2016-08-09
#   Processing day I: 2016-08-10
#   Processing day I: 2016-08-09
#   Processing day I: 2016-08-10
#   Processing day I: 2016-08-11
#   Processing day I: 2016-08-10
#   Processing day I: 2016-08-11
#   Processing day I: 2016-08-12
#   Processing day I: 2016-08-11
#   Processing day I: 2016-08-12
#   Processing day I: 2016-08-13
#   Processing day I: 2016-08-12
#   Processing day I: 2016-08-13
#   Processing day I: 2016-08-14
#   Processing day I: 2016-08-13
#   Processing day I: 2016-08-14
#   Processing day I: 2016-08-15
#   Processing day I: 2016-08-14
#   Processing day I: 2016-08-15
#   Processing day I: 2016-08-16
#   Processing day I: 2016-08-15
#   Processing day I: 2016-08-16
#   Processing day I: 2016-08-17
#   Processing day I: 2016-08-16
#   Processing day I: 2016-08-17
#   Processing day I: 2016-08-18
#   Processing day I: 2016-08-17
#   Processing day I: 2016-08-18
#   Processing day I: 2016-08-19
#   Processing day I: 2016-08-18
#   Processing day I: 2016-08-19
#   Processing day I: 2016-08-20
#   Processing day I: 2016-08-19
#   Processing day I: 2016-08-20
#   Processing day I: 2016-08-21
#   Processing day I: 2016-08-20
#   Processing day I: 2016-08-21
#   Processing day I: 2016-08-22
#   Processing day I: 2016-08-21
#   Processing day I: 2016-08-22
#   Processing day I: 2016-08-23
#   Processing day I: 2016-08-22
#   Processing day I: 2016-08-23
#   Processing day I: 2016-08-24
#   Processing day I: 2016-08-23
#   Processing day I: 2016-08-24
#   Processing day I: 2016-08-25
#   Processing day I: 2016-08-24
#   Processing day I: 2016-08-25
#   Processing day I: 2016-08-26
#   Processing day I: 2016-08-25
#   Processing day I: 2016-08-26
#   Processing day I: 2016-08-27
#   Processing day I: 2016-08-26
#   Processing day I: 2016-08-27
#   Processing day I: 2016-08-28
#   Processing day I: 2016-08-27
#   Processing day I: 2016-08-28
#   Processing day I: 2016-08-29
#   Processing day I: 2016-08-28
#   Processing day I: 2016-08-29
#   Processing day I: 2016-08-30
#   Processing day I: 2016-08-29
#   Processing day I: 2016-08-30
#   Processing day I: 2016-08-31
#   Processing day I: 2016-08-30
#   Processing day I: 2016-08-31
#   Processing day I: 2016-09-01
#   Processing day I: 2016-08-31
#   Processing day I: 2016-09-01
#   Processing day I: 2016-09-02
#   Processing day I: 2016-09-01
#   Processing day I: 2016-09-02
#   Processing day I: 2016-09-03
#   Processing day I: 2016-09-02
#   Processing day I: 2016-09-03
#   Processing day I: 2016-09-04
#   Processing day I: 2016-09-03
#   Processing day I: 2016-09-04
#   Processing day I: 2016-09-05
#   Processing day I: 2016-09-04
#   Processing day I: 2016-09-05
#   Processing day I: 2016-09-06
#   Processing day I: 2016-09-05
#   Processing day I: 2016-09-06
#   Processing day I: 2016-09-07
#   Processing day I: 2016-09-06
#   Processing day I: 2016-09-07
#   Processing day I: 2016-09-08
#   Processing day I: 2016-09-07
#   Processing day I: 2016-09-08
#   Processing day I: 2016-09-09
#   Processing day I: 2016-09-08
#   Processing day I: 2016-09-09
#   Processing day I: 2016-09-10
#   Processing day I: 2016-09-09
#   Processing day I: 2016-09-10
#   Processing day I: 2016-09-11
#   Processing day I: 2016-09-10
#   Processing day I: 2016-09-11
#   Processing day I: 2016-09-12
#   Processing day I: 2016-09-11
#   Processing day I: 2016-09-12
#   Processing day I: 2016-09-13
#   Processing day I: 2016-09-12
#   Processing day I: 2016-09-13
#   Processing day I: 2016-09-14
#   Processing day I: 2016-09-13
#   Processing day I: 2016-09-14
#   Processing day I: 2016-09-15
#   Processing day I: 2016-09-14
#   Processing day I: 2016-09-15
#   Processing day I: 2016-09-16
#   Processing day I: 2016-09-15
#   Processing day I: 2016-09-16
#   Processing day I: 2016-09-17
#   Processing day I: 2016-09-16
#   Processing day I: 2016-09-17
#   Processing day I: 2016-09-18
#   Processing day I: 2016-09-17
#   Processing day I: 2016-09-18
#   Processing day I: 2016-09-19
#   Processing day I: 2016-09-18
#   Processing day I: 2016-09-19
#   Processing day I: 2016-09-20
#   Processing day I: 2016-09-19
#   Processing day I: 2016-09-20
#   Processing day I: 2016-09-21
#   Processing day I: 2016-09-20
#   Processing day I: 2016-09-21
#   Processing day I: 2016-09-22
#   Processing day I: 2016-09-21
#   Processing day I: 2016-09-22
#   Processing day I: 2016-09-23
#   Processing day I: 2016-09-22
#   Processing day I: 2016-09-23
#   Processing day I: 2016-09-24
#   Processing day I: 2016-09-23
#   Processing day I: 2016-09-24
#   Processing day I: 2016-09-25
#   Processing day I: 2016-09-24
#   Processing day I: 2016-09-25
#   Processing day I: 2016-09-26
#   Processing day I: 2016-09-25
#   Processing day I: 2016-09-26
#   Processing day I: 2016-09-27
#   Processing day I: 2016-09-26
#   Processing day I: 2016-09-27
#   Processing day I: 2016-09-28
#   Processing day I: 2016-09-27
#   Processing day I: 2016-09-28
#   Processing day I: 2016-09-29
#   Processing day I: 2016-09-28
#   Processing day I: 2016-09-29
#   Processing day I: 2016-09-30
#   Processing day I: 2016-09-29
#   Processing day I: 2016-09-30
#   Processing day I: 2016-10-01
#   Processing day I: 2016-09-30
#   Processing day I: 2016-10-01
#   Processing day I: 2016-10-02
#   Processing day I: 2016-10-01
#   Processing day I: 2016-10-02
#   Processing day I: 2016-10-03
#   Processing day I: 2016-10-02
#   Processing day I: 2016-10-03
#   Processing day I: 2016-10-04
#   Processing day I: 2016-10-03
#   Processing day I: 2016-10-04
#   Processing day I: 2016-10-05
#   Processing day I: 2016-10-04
#   Processing day I: 2016-10-05
#   Processing day I: 2016-10-06
#   Processing day I: 2016-10-05
#   Processing day I: 2016-10-06
#   Processing day I: 2016-10-07
#   Processing day I: 2016-10-06
#   Processing day I: 2016-10-07
#   Processing day I: 2016-10-08
#   Processing day I: 2016-10-07
#   Processing day I: 2016-10-08
#   Processing day I: 2016-10-09
#   Processing day I: 2016-10-08
#   Processing day I: 2016-10-09
#   Processing day I: 2016-10-10
#   Processing day I: 2016-10-09
#   Processing day I: 2016-10-10
#   Processing day I: 2016-10-11
#   Processing day I: 2016-10-10
#   Processing day I: 2016-10-11
#   Processing day I: 2016-10-12
#   Processing day I: 2016-10-11
#   Processing day I: 2016-10-12
#   Processing day I: 2016-10-13
#   Processing day I: 2016-10-12
#   Processing day I: 2016-10-13
#   Processing day I: 2016-10-14
#   Processing day I: 2016-10-13
#   Processing day I: 2016-10-14
#   Processing day I: 2016-10-15
#   Processing day I: 2016-10-14
#   Processing day I: 2016-10-15
#   Processing day I: 2016-10-16
#   Processing day I: 2016-10-15
#   Processing day I: 2016-10-16
#   Processing day I: 2016-10-17
#   Processing day I: 2016-10-16
#   Processing day I: 2016-10-17
#   Processing day I: 2016-10-18
#   Processing day I: 2016-10-17
#   Processing day I: 2016-10-18
#   Processing day I: 2016-10-19
#   Processing day I: 2016-10-18
#   Processing day I: 2016-10-19
#   Processing day I: 2016-10-20
#   Processing day I: 2016-10-19
#   Processing day I: 2016-10-20
#   Processing day I: 2016-10-21
#   Processing day I: 2016-10-20
#   Processing day I: 2016-10-21
#   Processing day I: 2016-10-22
#   Processing day I: 2016-10-21
#   Processing day I: 2016-10-22
#   Processing day I: 2016-10-23
#   Processing day I: 2016-10-22
#   Processing day I: 2016-10-23
#   Processing day I: 2016-10-24
#   Processing day I: 2016-10-23
#   Processing day I: 2016-10-24
#   Processing day I: 2016-10-25
#   Processing day I: 2016-10-24
#   Processing day I: 2016-10-25
#   Processing day I: 2016-10-26
#   Processing day I: 2016-10-25
#   Processing day I: 2016-10-26
#   Processing day I: 2016-10-27
#   Processing day I: 2016-10-26
#   Processing day I: 2016-10-27
#   Processing day I: 2016-10-28
#   Processing day I: 2016-10-27
#   Processing day I: 2016-10-28
#   Processing day I: 2016-10-29
#   Processing day I: 2016-10-28
#   Processing day I: 2016-10-29
#   Processing day I: 2016-10-30
#   Processing day I: 2016-10-29
#   Processing day I: 2016-10-30
#   Processing day I: 2016-10-31
#   Processing day I: 2016-10-30
#   Processing day I: 2016-10-31
#   Processing day I: 2016-11-01
#   Processing day I: 2016-10-31
#   Processing day I: 2016-11-01
#   Processing day I: 2016-11-02
#   Processing day I: 2016-11-01
#   Processing day I: 2016-11-02
#   Processing day I: 2016-11-03
#   Processing day I: 2016-11-02
#   Processing day I: 2016-11-03
#   Processing day I: 2016-11-04
#   Processing day I: 2016-11-03
#   Processing day I: 2016-11-04
#   Processing day I: 2016-11-05
#   Processing day I: 2016-11-04
#   Processing day I: 2016-11-05
#   Processing day I: 2016-11-06
#   Processing day I: 2016-11-05
#   Processing day I: 2016-11-06
#   Processing day I: 2016-11-07
#   Processing day I: 2016-11-06
#   Processing day I: 2016-11-07
#   Processing day I: 2016-11-08
#   Processing day I: 2016-11-07
#   Processing day I: 2016-11-08
#   Processing day I: 2016-11-09
#   Processing day I: 2016-11-08
#   Processing day I: 2016-11-09
#   Processing day I: 2016-11-10
#   Processing day I: 2016-11-09
#   Processing day I: 2016-11-10
#   Processing day I: 2016-11-11
#   Processing day I: 2016-11-10
#   Processing day I: 2016-11-11
#   Processing day I: 2016-11-12
#   Processing day I: 2016-11-11
#   Processing day I: 2016-11-12
#   Processing day I: 2016-11-13
#   Processing day I: 2016-11-12
#   Processing day I: 2016-11-13
#   Processing day I: 2016-11-14
#   Processing day I: 2016-11-13
#   Processing day I: 2016-11-14
#   Processing day I: 2016-11-15
#   Processing day I: 2016-11-14
#   Processing day I: 2016-11-15
#   Processing day I: 2016-11-16
#   Processing day I: 2016-11-15
#   Processing day I: 2016-11-16
#   Processing day I: 2016-11-17
#   Processing day I: 2016-11-16
#   Processing day I: 2016-11-17
#   Processing day I: 2016-11-18
#   Processing day I: 2016-11-17
#   Processing day I: 2016-11-18
#   Processing day I: 2016-11-19
#   Processing day I: 2016-11-18
#   Processing day I: 2016-11-19
#   Processing day I: 2016-11-20
#   Processing day I: 2016-11-19
#   Processing day I: 2016-11-20
#   Processing day I: 2016-11-21
#   Processing day I: 2016-11-20
#   Processing day I: 2016-11-21
#   Processing day I: 2016-11-22
#   Processing day I: 2016-11-21
#   Processing day I: 2016-11-22
#   Processing day I: 2016-11-23
#   Processing day I: 2016-11-22
#   Processing day I: 2016-11-23
#   Processing day I: 2016-11-24
#   Processing day I: 2016-11-23
#   Processing day I: 2016-11-24
#   Processing day I: 2016-11-25
#   Processing day I: 2016-11-24
#   Processing day I: 2016-11-25
#   Processing day I: 2016-11-26
#   Processing day I: 2016-11-25
#   Processing day I: 2016-11-26
#   Processing day I: 2016-11-27
#   Processing day I: 2016-11-26
#   Processing day I: 2016-11-27
#   Processing day I: 2016-11-28
#
# === BUILD DATASET SUMMARY ===
# Total candidate windows: 3036
# Accepted samples: 2758
# Rejected windows: 278
#   - rejected due to day aggregation: 278
#   - rejected due to NaN target: 0
# Final X shape: (2758, 39)
# Final Y shape: (2758, 1)
# === BUILD DATASET END ===

# %%
import pandas as pd

df = pd.DataFrame(X)
df.head()
# Out:
#          0       1       2          3     4     5            6       7   \
# 0  279.7266  279.07  280.37  83.318182  70.0  93.0  1010.052632  1003.0
# 1  282.9832  281.36  284.93  89.052632  76.0  93.0  1013.000000  1006.0
# 2  284.9656  283.14  286.10  86.080000  76.0  92.0  1017.240000  1013.0
# 3  282.0260  281.20  284.05  90.391304  87.0  93.0  1018.952381  1011.0
# 4  281.8052  279.46  283.22  75.958333  53.0  93.0  1016.095238  1011.0
#
#        8     9   ...         29    30     31           32      33      34  \
# 0  1015.0  3.56  ...  80.347826  70.0   93.0  1019.888889  1009.0  1030.0
# 1  1028.0  1.92  ...  92.750000  87.0  100.0  1005.444444   997.0  1025.0
# 2  1029.0  2.68  ...  75.958333  53.0   93.0  1016.095238  1011.0  1019.0
# 3  1027.0  1.80  ...  78.750000  65.0   86.0  1013.954545  1011.0  1026.0
# 4  1019.0  3.92  ...  64.086957  45.0   81.0  1011.958333  1011.0  1013.0
#
#      35    36        37        38
# 0  3.20   7.0  0.944376  0.328867
# 1  3.16   9.0  0.964465  0.264210
# 2  3.92   9.0 -0.166769 -0.985996
# 3  3.92  10.0  0.487860 -0.872922
# 4  1.60   8.0  0.766044 -0.642788
#
# [5 rows x 39 columns]
